# %%
from mh_dist_polygon import BhuNakshaExtractor
import random

CATEGORY = 'U' 
# List of districts you want to scrape
TARGET_DISTRICTS = ["Mumbai City", "Mumbai Sub-Urban"]
# Delay in seconds between each plot request to be respectful to the server
DELAY_BETWEEN_PLOTS_RANGE = (0.2, 2)
    
extractor = BhuNakshaExtractor(state="27", category=CATEGORY)
extractor.scrape_districts(
    target_districts=TARGET_DISTRICTS,
    delay_per_plot_range=DELAY_BETWEEN_PLOTS_RANGE
)
print("\nScraping process finished.")
# Out:
# Initializing session...
# Starting scrape for districts: ['Mumbai City', 'Mumbai Sub-Urban']
#
# Processing District: Mumbai City (Code: 23)
#   -> Discovering all taluks...
#   -> Found 1 taluks.
#   -> Processing Taluk: Mumbai City (Code: 01)
#     -> Found existing file for 'BHULESHWAR' with 4480 plots. Resuming...
#     ✅ Village 'BHULESHWAR' has 4480 total plots.
#     -> All 4480 plots for 'BHULESHWAR' already scraped. Skipping.
#     -> Found existing file for 'BYCULLA' with 2509 plots. Resuming...
#     ✅ Village 'BYCULLA' has 2509 total plots.
#     -> All 2509 plots for 'BYCULLA' already scraped. Skipping.
#     -> Found existing file for 'COLABA' with 716 plots. Resuming...
#     ✅ Village 'COLABA' has 716 total plots.
#     -> All 716 plots for 'COLABA' already scraped. Skipping.
#     -> Found existing file for 'DADAR-NAIGAUM' with 915 plots. Resuming...
#     ✅ Village 'DADAR-NAIGAUM' has 915 total plots.
# ...
